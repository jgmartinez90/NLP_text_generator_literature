# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
from keras.models import load_model
from keras import backend as K
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:458: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:459: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:460: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:461: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:462: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/imprs/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:465: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
text = io.open('resources/shakespeare.txt', encoding='utf-8').read().lower()

print('corpus length:', len(text))
# Out:
# corpus length: 4030190

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
# Out:
# total chars: 58

# %%
seqlen = 40 # Sequence length parameter
step = 5   # Determines the how many characters the window should be shifted in the text 
sequences = []  # List of sequences
char_class = [] # Corresponding class of each sequence

for i in range(0, len(text) - seqlen, step):
    sequences.append(text[i: i + seqlen])
    char_class.append(text[i + seqlen])
print('#no sequences:', len(sequences))
# Out:
# #no sequences: 806030

# %%
for idx in range(len(sequences[:10])):
    print(sequences[idx], ":" , char_class[idx])
# Out:
# 1609
#
# the sonnets
#
# by william shakespear : e
#
# the sonnets
#
# by william shakespeare
#
#
#
#  :
# sonnets
#
# by william shakespeare
#
#
#
#       :
# ts
#
# by william shakespeare
#
#
#
#            :
# y william shakespeare
#
#
#
#                 :
# liam shakespeare
#
#
#
#                      :
# shakespeare
#
#
#
#                      1
#    : f
# speare
#
#
#
#                      1
#   from  : f
# e
#
#
#
#                      1
#   from faire : s
#                      1
#   from fairest cr : e

# %%
# Print from 1st to 10th character 
chars[:10]
# Out:
# ['\n', ' ', '!', '"', '&', "'", '(', ')', ',', '-']

# %%
# Indexed characters as dictionary
char_indices = dict((c, i) for i, c in enumerate(chars))

# Both matrices will initialized with zeros
training_set = np.zeros((len(sequences), seqlen, len(chars)), dtype=np.bool)
target_char = np.zeros((len(sequences), len(chars)), dtype=np.bool)
for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        training_set[i, t, char_indices[char]] = 1
    target_char[i, char_indices[char_class[i]]] = 1

# %%
training_set.shape
# Out:
# (806030, 40, 58)

# %%
target_char.shape
# Out:
# (806030, 58)

# %%
model = Sequential()

#LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)

model.compile(loss='categorical_crossentropy', optimizer=optimizer)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95744
# _________________________________________________________________
# dense_1 (Dense)              (None, 58)                7482
# _________________________________________________________________
# activation_1 (Activation)    (None, 58)                0
# =================================================================
# Total params: 103,226
# Trainable params: 103,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
def getNextCharIdx(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# Creation of reverse char index, to get the char for the predicted class
indices_char = dict((i, c) for i, c in enumerate(chars))

def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    start_index = random.randint(0, len(text) - seqlen - 1)
    for diversity in [1, 0.1, 0.5]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + seqlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(1000):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = getNextCharIdx(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(training_set, target_char,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.6733
# ----- Generating text after Epoch: 0
# ----- diversity: 1
# ----- Generating with seed: "nd arviragus
#
#   belarius. you, polydore,"
# nd arviragus
#
#   belarius. you, polydore, my bords, and all welcome,
#     well versing his die not lave melen,
#     weepedtipt in th' servance. i could proper.
#   nos. ne le-ing so't's no ene?
#   couried my lord.
#     betwoen in the setten french in the di,
#     terk, be wordall; bed.
#   glord. feenie hove comeatice, as he know i formestzoves.
#   halooucd. fair here leaves honour, ewen edfull.
#                     exit where now
#     come as good be disbought sild os my
#     not obporrnw to the tomber hunch to duken. i must do wast,
#     i deever wownse may not bawr is lost come
#     as say goven'd enough strangerritus,
#     woa, you well; you we'll herefore, shall he heer notmad
#     tabkingh, my hunies in the on 'o barder
#     from a unpegue, hereful. aftece and own hopely brigely
#     whus an  o, ermirior, a day win othemon.
#   com. . i do come take there.
#   cousinor.        exit.
#     he will i' on for thweramiers
#
#   ?
# tebbess distor'd requining a
#     and fer her somen viruser you dear and giors?
#   cassio. if a untonder's cistols'd some n
# ----- diversity: 0.1
# ----- Generating with seed: "nd arviragus
#
#   belarius. you, polydore,"
# nd arviragus
#
#   belarius. you, polydore, be the wart to her soul the beat of the soul the son
#     and some the beard to be the will not so love
#     and be the will the soul the which the soul destretter be the beard.
#
# ----- diversity: 0.5
# ----- Generating with seed: "nd arviragus
#
#   belarius. you, polydore,"
# nd arviragus
#
#   belarius. you, polydore, the come against men therefore.
#     and here on the counter and feats some contine
#     to well none, devis may be the healt.
#                 exit
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        exeunt
#
# enter elour are be a borth more beards of his falstares.
#     this son edwand england, the means fall sooks here of it.
#
# 806030/806030 [==============================] - 2062s - loss: 1.6733
# Epoch 2/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4868
# ----- Generating text after Epoch: 1
# ----- diversity: 1
# ----- Generating with seed: "crown him ere't be long.'
#   king edward."
# crown him ere't be long.'
#   king edward. gave courty fee's weach,es live. be ward
#     soft shever from venice aftitting, you
#     see here aht my in gures, made all sme.
#
#     and on the look sweet inher sivs;
#     to
#     chose but that bewidal of treace he care waven their.
#   isables forus. so with him the truth
#                                 pray himor of with speet a
#    ake for the witd, i will upitiant acd.
#     then, the peal touch his honanicy, my hoste,
#     the towerd. ale the weagt wior carden your hy death
#     to arl my greet have last'd wide, what,
#     what nit my nor roouned macint
#     pail mouthard adise hands of my reeptry
#     to him of dustich all goot.
#   king. when far when you shall not force,
#     hup with the bowidius not of where; for they.
#     macceet be edward me, of think.
#   pider. there is me, your so love.
#     great that their hear.'
#   omitio. a, aulight?
#   vise. a enfect the child hot of mine?
#     we i prof witas in these sould, with our here on
#     is braisou, thes of more bebrants
# discation, i liwn o
# ----- diversity: 0.1
# ----- Generating with seed: "crown him ere't be long.'
#   king edward."
# crown him ere't be long.'
#   king edward.
# ----- diversity: 0.5
# ----- Generating with seed: "crown him ere't be long.'
#   king edward."
# crown him ere't be long.'
#   king edward. you are thee the world me;
#     with me be merent should be thee are as with thy
#     have you be the death and wall all her;
#     the sent a brow duke of the heart man's her
#     cast thee of my sace, this hearted me.
#     the witch is come all the beath with this fall're dame
#     the prothen the proceit in all wind me,
#     a wife the wit of this mine of the come,
#     i must it the siver this first and the soul live
#     in the hear my crown and thee the arms and ack a bear thee,
#     the worster and the purpose him stand in soul the pols of in enter
#     of the court, of the sconding it we will
#     the with your bear the infire come and made gratts
#     which comes a tooth we be of me and shall and the made me with a scrived
#     as the man and the prince of his true all more.
#     and this be grieve is were he not be readen her you
#     your he hath speak the thoust of her fear,
#     your had lord with him and laguious with poith a good men all and offence in your could with they should some wi
# 806030/806030 [==============================] - 2067s - loss: 1.4868
# Epoch 3/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4532
# ----- Generating text after Epoch: 2
# ----- diversity: 1
# ----- Generating with seed: "suffolk
#
#   norfolk. well met, my lord ch"
# suffolk
#
#   norfolk. well met, my lord charge
#     sailling traided; it could find deposs.
#     see drest may sing his wout the fest give me says henry, if you cannot
#     for sonilett. nawerrable you may is lating, and may do not doth shake
#      speak him is claols and strittly antony,
#     we be are now!   entred at her command, of it your timpreg;
#     ens hadomay the duke. as criglt, why.
#   sents. i am praceaster' aftetn, if.
#      nature? not services, gentleman, frors,
#     and a miness.
#   glou. a pleased desdom the proves my loven.
# antipholus of sirilian, and othant, why soveren the poul red me.
#   thy wife states thou hasts sep the like a guiery.
#   better a first and lifed the hand.
#   engedidia. gaurn, all where cowans, looks, no, sir, i creople thee.
#   lates. live
#   carda, friend duke of swift, fishour., leal fight
#     it, naglian timas leave me oft not entate.
#                                           ange knows his.
#   pear. if doth men doy, even well cannot by this naits,
#     ace enobour vilage. so man's sepeat.
# antibrao.
# ----- diversity: 0.1
# ----- Generating with seed: "suffolk
#
#   norfolk. well met, my lord ch"
# suffolk
#
#   norfolk. well met, my lord charge to the complete when he will see my sent to the father and man and sent the combony.
#
# ----- diversity: 0.5
# ----- Generating with seed: "suffolk
#
#   norfolk. well met, my lord ch"
# suffolk
#
#   norfolk. well met, my lord charge you seek the chamber.
#   king henry. the more. you that be man in men and better a states.
#     and you blow in the fairen and angelow for a chinge.
#     the what is the nothing do consuse you a smings,
#     in this estis'd and good as send you so good men
#     is a arming letters the princes to me.
#     by the sent and good one hand and heart.
#     that was think the heart of the comment some most sent'd his will's more.
# 806030/806030 [==============================] - 2081s - loss: 1.4532
# Epoch 4/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4382
# ----- Generating text after Epoch: 3
# ----- diversity: 1
# ----- Generating with seed: "s.
#   coriolanus. traitor! how now?
#   auf"
# s.
#   coriolanus. traitor! how now?
#   auford. way, who, my lord.
#   anch. ho? had. for it but to remevcetor this ah
#     not thy daughted prochant, that keep thee thus oft.
#     i tell lead a grander that high.
#   queen margaret. i did no some heart of it: stasbour devil asumal.
#          mine smeer him speak, hore; is a more,
#     we tok'st or rosalind at then do
# ; then that is tyounessic dews os warel him then.
#   well. though sepitch put it were intere thou'st so you
#   far enecitark, but you enterent bestren hers metching, do fight peoples,
#     good for him or thy had command practol maystor,
#     which not though to keeps ever therean brain
#   signd hope. no, well ano, and beldes mades upon do releas,
#     blow him peti'd were of master, when you?
#
#   king. if that! for anoo. have he in helliresable counder unto so good,
#     for thou walt he. good byress? i will that but some basing you
#     a capitoding on on young.
#   brutus. how be petted of bastar.
#   probisonie justius. my lord, yield thoster.  . bucking pienc hath sigous ol
# ----- diversity: 0.1
# ----- Generating with seed: "s.
#   coriolanus. traitor! how now?
#   auf"
# s.
#   coriolanus. traitor! how now?
#   aufidius. there is thee that stand thee thee.
#
# ----- diversity: 0.5
# ----- Generating with seed: "s.
#   coriolanus. traitor! how now?
#   auf"
# s.
#   coriolanus. traitor! how now?
#   aufe. all our sleep of me. the love to the wounds the the some and then that matters and many do lady.
#   porth. and but therefore have mee hear an in a lead thine or for so and appleas.
#     the powers that for the sense me some for then
#     what thank he shall i can call our to see them.
#     how with the parish then there and sleep,
#                                                                                                                                                                                                                                                                                        exit stand on her i then made. and then
#     that gentleman of the great are viil degrance.
#     if he in these that you change and men thee.
#     that i have courted a counter that that shall say in me
#     he is a personad that is that all remembers especious with him.
#
# 806030/806030 [==============================] - 2068s - loss: 1.4382
# Epoch 5/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4403
# ----- Generating text after Epoch: 4
# ----- diversity: 1
# ----- Generating with seed: "d. away, then, with good courage!
#     ye"
# d. away, then, with good courage!
#     yet behold i ploten than'd hell. sam, why, look shall he with kick sad ceote;
#     and else deed! cruel'st ent's neigh to dorn much should
#     forth'll all it be less'd aid mare another
#     these agol it my lov'd his conspling;
#     and all ill my from a friends and deare.
#   lear. our own so what bears yo
# /home/imprs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# u.
#   dog. a granto.
#   well. o. in this quink the seld benemaed, the buturess.
#   bartard are gracinent. o, and you are a thing mls; it will gs; that's behamk fuither, and thy laldey gomblesue
#     french misswing and shall miss, and parting all crown!
#
#                 enter call it how ye will vilegn your greatdess;
#     fears. why, sir-alof of nighing dursiay dirstm need, my father- sirray,
#     should here mights he gain ans i nothing loves;
#     we are rigs hands we. well wead, i'll still a
#   case! ay, then his down how in onfest'ste;
#     parts my loon and his head it pridely of daughter.
#                                             exit further.
# ----- diversity: 0.1
# ----- Generating with seed: "d. away, then, with good courage!
#     ye"
# d. away, then, with good courage!
#     yet the strain the court heart the theme the sense of the send the send the send the send the send the strain the sense.
#
# ----- diversity: 0.5
# ----- Generating with seed: "d. away, then, with good courage!
#     ye"
# d. away, then, with good courage!
#     yet thou art bring the mouth.
#     i think i have the fear of corn, here's a times.
#
# 806030/806030 [==============================] - 2079s - loss: 1.4404
# Epoch 6/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4368
# ----- Generating text after Epoch: 5
# ----- diversity: 1
# ----- Generating with seed: " you grow foul with me, pistol, i
#     wi"
#  you grow foul with me, pistol, i
#     with when the completed to seiing on hors big thee.
#   owno. thou love gienssbus these his man aivited scelanors! in myord;
#                  say not the man, by the cre mistress stoulves
#     the john- has we be answall. they not thou do be amadness hath be friends it;
#     th's answor our lists of claredy beatongmon,
#     this place it-forth and one nymuse double.
#   wholee mind may be man how with one thy hearts
#     to thou grantsaphse die, his hand in the army a
#   clarence and a philizent compassing upon
#     sent, did
#     sendy they have dispeohing it would how is me
#     see, margarets can tell al was hearts,
#     misporch like as the bloody of of thien?
#   emobus, comuch a figathrivine, who sloone,
#     and it is speak on the blace.
#     to half not no morrows bladellat on used
#         so king blood- a prodeds in the sea.
#     breed, of throwhond and pro'd come with the king he here
#     not the father that hath mobe all.
#   constague. where is a rakether brought befor you landed,
#     should
# ----- diversity: 0.1
# ----- Generating with seed: " you grow foul with me, pistol, i
#     wi"
#  you grow foul with me, pistol, i
#     with the prosent the stand the send the world and the prove the world the prosent
#     the send the prince of the prosent the songlow the princesses of the princess of the prohen
# wi lower complethesdgren0-
#   come is the stand the complethes will.
#
# ----- diversity: 0.5
# ----- Generating with seed: " you grow foul with me, pistol, i
#     wi"
#  you grow foul with me, pistol, i
#     with love me the gracinius to his come,
#     but the fair on the compantions of the parting.
#     the wars to make the great be and son son
#     and death, i will blinger and wall and this most will deal mine.
#     i'll disposite that i will cuses thou slave it li' me the sing of the bear.
#     and this honest that is my coming at the grace be so not will deserv'd
#     and a good thou art the man of the will gall purpose.
#     the presence he hath thou wars to have have so't i have a sense
#     which is the broken thou shalt spirit of the come for the bearing.
#
# 806030/806030 [==============================] - 2045s - loss: 1.4369
# Epoch 7/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4545
# ----- Generating text after Epoch: 6
# ----- diversity: 1
# ----- Generating with seed: "noble housewife with the time,
#     to en"
# noble housewife with the time,
#     to england
#     to thee thou lip, time me make him?
#   bertram. you al scown to speak me not mrson. nay, my dear madest day
#     ispepity would not tok for guard your anton spariords, quiecty.
#   imuna. sir, lady me your redm'dry this;
#     if he their laftion o' th' as o
#     burn accale as he any the any, it speak
#     dost to singless
#     will no land no manners and not to sticiad,
#     that her thy cramious dull, our awress.
#   lauph. is. snarr, impose to shid?
#   all. i make meet, medus the drudus agers. thy, and both not!
#     i'll the heart 'tis eat filld, and the armant and which
#     oak in i will i farad 'a floots met'd in willy.
#   cascio. and yes, which but these shallower to you of your exemphince.
#   first trustain;
#     god the make mistress pray of so daughting
#
#   coriolanus. thatg'd it.
#   first buck. but but head
#     a will to dog at a ganure checked did so with you in cloovy time
#     upon this light his per.
#   bertram. no young poor foul to confissus'd eall
#     bud to me
#     against th
# ----- diversity: 0.1
# ----- Generating with seed: "noble housewife with the time,
#     to en"
# noble housewife with the time,
#     to endure to the man the company thanks and this to the prince of the counters and the for the barth and the bander
#     to the prince of the bear the to the seem and the send the words and the bear the bear the come in the send the seem and this and the seem and this best the prince of the bear the man the bear the words and this be and this and the to the seem and see the seem and the world
#     to the man that the bear the beat the words to the prince of the world
#     that the beat of this make the man the company
#     that the prince to the company thanks that the bear the world the common thanks and this to the seem and the for the best the prince of the come in the borne the bear the bellow and the bear the belliant thanks and the common thanks and the seem and see the father;
#     and the beat the barth that the bear the world the company
#     the world to the barth that the bear the send the bear the bardon and this to the send the for the duke of this best the come in the come to the co
# ----- diversity: 0.5
# ----- Generating with seed: "noble housewife with the time,
#     to en"
# noble housewife with the time,
#     to enemmes by and a truth thinker that in the gives the intoniony for his state.
#     thou shalt say i mark this her camperal best side with a soul thanks of this now.
#     i'll reporn that followed to his counddmor do be with a charment.
#     i sad well the counter and the time of my countes.
#     i shall not have the ermian would now it and his most may be follow poor
#     though a wit to the shorth of to make my grace.
#   cassio. i may been in this this and man that made your play to thanking
#     and thousand prince of your hours, and the seem
#     to the come not thou lips in this purpose and will
#     the servance of his at his tongues, and before it he is the to see me or the words.
#     hear that the speed blession his can of your house. readay in thy great coventer to the sad to see the duke each
#     in this in this before i dead thee the commoness and see the loke to i before a this than thou art that more and fear thanks her heart
#     by this our him for his thing blood than they in the co
# 806030/806030 [==============================] - 2069s - loss: 1.4545
# Epoch 8/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4584
# ----- Generating text after Epoch: 7
# ----- diversity: 1
# ----- Generating with seed: "her to me;
#     i'll make him find him. d"
# her to me;
#     i'll make him find him. do all my phitiouly in the purath come come come thempequalier of to not he most.
#             exeits.el's comming, this thou.
# probo.
#   i feepy thy withciois, have your shiful and to you head.
#     looking. th' as that their for your uouy silvethe!
#     the post scarus up 'weah his king!
#   me in fairy for him my be calf know for his chow allay
#                  that hid.
#   arhfuls, entter of quick; him carse. i will speak, you cow shall they. here. the for his boons, the to looks
#     that would mouth, and fellow jot intim,
#     his goners as i for better.
#
#                                                                               exit che'lest wout that,
#     entergled. four, i do so moreked than ephthalllows meanty.
#     an i art, best kind, attemiss all,
#     ad, and that him that stick but
#     as god's camnce maphectier sreath'd to such knews
# distavia.
#     my spirick the pomper of th' heart.
#   rostand. a that says, the night
#     your fores all his sead me
#     criey, hall sirrage.
#   pie si
# ----- diversity: 0.1
# ----- Generating with seed: "her to me;
#     i'll make him find him. d"
# her to me;
#     i'll make him find him. do not a sent the stand the the the the the stand the them the sicionement and the them the them the sight
#     the the the come the the the that the the the that the thing the the the the the come the the the the the proved of me
#     the duke to the come the the the the the the the the stand the stand the the the come the the that the the sicionebkes the them the the the the the the the the the the the the that the the the beard the come the the the the the the the the with the that the come the the the that the sicion and the them the souls.
#     the heart the the the come the the the the the the the that the the come the beard the the word,
#     and the come the the the the the man of the them the sent of the them
#     the the man of the heart and the the the sicionement and the state the them the them the sir best the the the the the the with the them the the the the the the the the the the the stand the the the the the man and the the the thing the stand the to the the the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "her to me;
#     i'll make him find him. d"
# her to me;
#     i'll make him find him. did in thing with the heart, my lord.                                                                                                                                                                                                                                                                                                                                                                                                                                                            exit
#
#
# 806030/806030 [==============================] - 2041s - loss: 1.4584
# Epoch 9/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4653
# ----- Generating text after Epoch: 8
# ----- diversity: 1
# ----- Generating with seed: "ency
#     to put a strange face on his ow"
# ency
#     to put a strange face on his own or be.
#   beam. i least goodfe of the cunsie of her
#     wert did, your fooling, good alte of myself,
#     the offillow.
#
# adraath so by thus is bring false
# anterms. were.
#   margel. i read the horse;
#     it by a falsticker by refame speaks, for not.
#   caiderioe. i impassure prince'slys of thiss?
#     and warks the sport, parteds of shuth,
#     she is horry, to roc roube
#     off.
#     dir the eadiants, fortw.
#   ilo, sovereithercs bothallittone,
#    this out of setiny. title by pistant. i have sweat,
#   pies.
#   ploutemen. my lord's griey.
#   cleo. your storeful accumes of fair for ye, rure.
#   forg. she hate offinenay my trass place. this harret;
#     bothing his name of a oine, my ladate sense.
#   reada. and but talkly so west-greece on thee bovey.
#     it be my,
#     o your bring is constramants to her dear!
#     news, for some. so my lord, my lords' furth yourselust byegn.
#     but neter
#   wise. i have have froll shall re
#   restress' the prince, proy still wouldst one,
#     and possess and they son
#
# ----- diversity: 0.1
# ----- Generating with seed: "ency
#     to put a strange face on his ow"
# ency
#     to put a strange face on his own the sense
#     the senses of the constain of the senses.
#     the sir the duty be the counters of the senses of the senses of the senses.
#     the life of the senses of the sent of the senses
#     the senses of the counters of the senses.
#     the life of the senses of the sensester.
#     the duty with the sent of the senses of the senses
#     the counters of the senses of the senses.
#     the sin the senses of the sensesters of the senses
#     the senses of the senses of the senses.
#     the life of the constant the sin the senses
#     the life the sin the sin the counters and the senses
#     the stand the senses of the senses of the senses.
#     the senses of the consent of the senses.
#     what the senses of the counters of the present.
#     the sin the senses of the countens of the servers of the senses.
#     the life the senses of the senses of the senses
#     the counters the senses of the constant.
#     the counters of the senses of the senses
#     the senses of the counters of the senses.
#     t
# ----- diversity: 0.5
# ----- Generating with seed: "ency
#     to put a strange face on his ow"
# ency
#     to put a strange face on his own the sens the bertime
#     bedf the prince of soul was his into my lord.
#     been are of the storns all of the princes.
#   coronatio. why, and you were he shall we see his lord of my duty
#
# 806030/806030 [==============================] - 2048s - loss: 1.4653
# Epoch 10/10
# 806016/806030 [============================>.] - ETA: 0s - loss: 1.4761
# ----- Generating text after Epoch: 9
# ----- diversity: 1
# ----- Generating with seed: " not that a good word?
#   dumain. i would"
#  not that a good word?
#   dumain. i would puecos,
#     the shousdond's pass. and to aith, my book
#     a powrided, nof albants, by his heart.
#   stald. cul, but presence's plais's. dids their inderself's impr man for my senses
#     seeman's dules viral of me of your bevellaious. he prince-russ.
#   simplier. i have sumpor'd oo give be a gars'd bhits,
#     for my good court, glances in king where is to dove?
#   gring! cassio!
#   cyall. i have wind gran hose to with and wake distouster,
#     worth's mewing advisers did past uphers,
#     there, fleph
#
#
# gravitagence.
#      the'st
#   cleopatra. the mounted find gontis, antony,
#     for all a discolingole to gey on these moth possedry sick,
#     than o no life in sels, down! his i this
#     how meance, speak'd me of brutus, to so recolit;
#     i now, our whetdmene like here unship laupus; if that
#     such eye, not is conence, look, anon.
#  ren. i fallt to foishording;
#     thear never to those other go where me, that yet consur'd; past innedne;
#     i pray on the mother it are i seel coustams i'll sla
# ----- diversity: 0.1
# ----- Generating with seed: " not that a good word?
#   dumain. i would"
#  not that a good word?
#   dumain. i would see the counter the dear the son of the court the strain the send the counters and the son and the son
#     the counter the send the stand the son the send the with the song the son and the counter and the son
#     the strange the discollence the presus the send the son the world.
#     the discoll the stand the counter the son and the for the souls,
#     and the counter the for the counter the counter the son
#     the counter the strange the discollence.
#     the presence the sick of the love the sir man the more to the for the send the son and the for the send the counter and the counter the counter the send the counter the son
#     the discoll the send the counter the send the sir prince,
#     and the counter the counter the counter the son to the son
#     the prince of the counter the for the counter the son
#     that the for the counter the counter the son of the counter the counter the son
#     the send the saliown the counter the counter the send the counter the counter the son and the son
# ----- diversity: 0.5
# ----- Generating with seed: " not that a good word?
#   dumain. i would"
#  not that a good word?
#   dumain. i would be myself of shown with the toon his counter our eyes,
#     with his strain that shall see heard the presuld.
#   sicinius. you are content to here the princes, and the kiss
#     that for the more promit the love of my to what eye.
#     the mofe and a princes in the counters
#     to be for me so to hear a celle, the capibible prince
#     the beaud the counter and whose will the man
#     do the man in your enemy and the more king?
#     but the lady counter in a the for the most love
#     the end the like all be be the fairen and this need
#     that would make the shorth some his life with maiden to praise their king than
#     than for the so discolless of love the villain
#     that have more the descends and more and the come,
#     the mountalt of the end with the present.
#   fere. what that monse the money than me,
#     the grace of the life him i have all the spar.
#     that should be make him our cound the hearts and down unley
#     with the king that the nothing of gloucester
#
# 806030/806030 [==============================] - 2053s - loss: 1.4761

# %%
model.save('shakespeareModel1.h5')
